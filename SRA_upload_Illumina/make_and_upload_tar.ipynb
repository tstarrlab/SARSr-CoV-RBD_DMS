# %% [markdown]
# # Create TAR file of FASTQs and upload to SRA
# This Python Jupyter notebook creates a `*.tar` file of the FASTQs and uploads them to the SRA.
#
# First, import Python modules:

# %%
import datetime
import ftplib
import os
import tarfile

import pandas as pd

import yaml

# %% [markdown]
# Read in the FASTQ files to upload:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)
    
fastqs = pd.read_csv('FASTQs_to_upload.csv')

# %% [markdown]
# Now we need to make a `*.tar` file with all of the files.
# Note that this step **will take a long time to run**.

# %%
tar_filename = 'SRA_submission.tar'

try:
    with tarfile.open(tar_filename, mode='w') as f:
        for i, tup in enumerate(fastqs.itertuples()):
            print(f"Adding file {i + 1} of {len(fastqs)} to {tar_filename}")
            f.add(tup.filename_fullpath, arcname=tup.filename)
        print(f"Added all files to {tar_filename}")
except:
    if os.path.isfile(tar_filename):
        os.remove(tar_filename)
    raise
# Out:
# Adding file 1 of 430 to SRA_submission.tar
# Adding file 2 of 430 to SRA_submission.tar
# Adding file 3 of 430 to SRA_submission.tar
# Adding file 4 of 430 to SRA_submission.tar
# Adding file 5 of 430 to SRA_submission.tar
# Adding file 6 of 430 to SRA_submission.tar
# Adding file 7 of 430 to SRA_submission.tar
# Adding file 8 of 430 to SRA_submission.tar
# Adding file 9 of 430 to SRA_submission.tar
# Adding file 10 of 430 to SRA_submission.tar
# Adding file 11 of 430 to SRA_submission.tar
# Adding file 12 of 430 to SRA_submission.tar
# Adding file 13 of 430 to SRA_submission.tar
# Adding file 14 of 430 to SRA_submission.tar
# Adding file 15 of 430 to SRA_submission.tar
# Adding file 16 of 430 to SRA_submission.tar
# Adding file 17 of 430 to SRA_submission.tar
# Adding file 18 of 430 to SRA_submission.tar
# Adding file 19 of 430 to SRA_submission.tar
# Adding file 20 of 430 to SRA_submission.tar
# Adding file 21 of 430 to SRA_submission.tar
# Adding file 22 of 430 to SRA_submission.tar
# Adding file 23 of 430 to SRA_submission.tar
# Adding file 24 of 430 to SRA_submission.tar
# Adding file 25 of 430 to SRA_submission.tar
# Adding file 26 of 430 to SRA_submission.tar
# Adding file 27 of 430 to SRA_submission.tar
# Adding file 28 of 430 to SRA_submission.tar
# Adding file 29 of 430 to SRA_submission.tar
# Adding file 30 of 430 to SRA_submission.tar
# Adding file 31 of 430 to SRA_submission.tar
# Adding file 32 of 430 to SRA_submission.tar
# Adding file 33 of 430 to SRA_submission.tar
# Adding file 34 of 430 to SRA_submission.tar
# Adding file 35 of 430 to SRA_submission.tar
# Adding file 36 of 430 to SRA_submission.tar
# Adding file 37 of 430 to SRA_submission.tar
# Adding file 38 of 430 to SRA_submission.tar
# Adding file 39 of 430 to SRA_submission.tar
# Adding file 40 of 430 to SRA_submission.tar
# Adding file 41 of 430 to SRA_submission.tar
# Adding file 42 of 430 to SRA_submission.tar
# Adding file 43 of 430 to SRA_submission.tar
# Adding file 44 of 430 to SRA_submission.tar
# Adding file 45 of 430 to SRA_submission.tar
# Adding file 46 of 430 to SRA_submission.tar
# Adding file 47 of 430 to SRA_submission.tar
# Adding file 48 of 430 to SRA_submission.tar
# Adding file 49 of 430 to SRA_submission.tar
# Adding file 50 of 430 to SRA_submission.tar
# Adding file 51 of 430 to SRA_submission.tar
# Adding file 52 of 430 to SRA_submission.tar
# Adding file 53 of 430 to SRA_submission.tar
# Adding file 54 of 430 to SRA_submission.tar
# Adding file 55 of 430 to SRA_submission.tar
# Adding file 56 of 430 to SRA_submission.tar
# Adding file 57 of 430 to SRA_submission.tar
# Adding file 58 of 430 to SRA_submission.tar
# Adding file 59 of 430 to SRA_submission.tar
# Adding file 60 of 430 to SRA_submission.tar
# Adding file 61 of 430 to SRA_submission.tar
# Adding file 62 of 430 to SRA_submission.tar
# Adding file 63 of 430 to SRA_submission.tar
# Adding file 64 of 430 to SRA_submission.tar
# Adding file 65 of 430 to SRA_submission.tar
# Adding file 66 of 430 to SRA_submission.tar
# Adding file 67 of 430 to SRA_submission.tar
# Adding file 68 of 430 to SRA_submission.tar
# Adding file 69 of 430 to SRA_submission.tar
# Adding file 70 of 430 to SRA_submission.tar
# Adding file 71 of 430 to SRA_submission.tar
# Adding file 72 of 430 to SRA_submission.tar
# Adding file 73 of 430 to SRA_submission.tar
# Adding file 74 of 430 to SRA_submission.tar
# Adding file 75 of 430 to SRA_submission.tar
# Adding file 76 of 430 to SRA_submission.tar
# Adding file 77 of 430 to SRA_submission.tar
# Adding file 78 of 430 to SRA_submission.tar
# Adding file 79 of 430 to SRA_submission.tar
# Adding file 80 of 430 to SRA_submission.tar
# Adding file 81 of 430 to SRA_submission.tar
# Adding file 82 of 430 to SRA_submission.tar
# Adding file 83 of 430 to SRA_submission.tar
# Adding file 84 of 430 to SRA_submission.tar
# Adding file 85 of 430 to SRA_submission.tar
# Adding file 86 of 430 to SRA_submission.tar
# Adding file 87 of 430 to SRA_submission.tar
# Adding file 88 of 430 to SRA_submission.tar
# Adding file 89 of 430 to SRA_submission.tar
# Adding file 90 of 430 to SRA_submission.tar
# Adding file 91 of 430 to SRA_submission.tar
# Adding file 92 of 430 to SRA_submission.tar
# Adding file 93 of 430 to SRA_submission.tar
# Adding file 94 of 430 to SRA_submission.tar
# Adding file 95 of 430 to SRA_submission.tar
# Adding file 96 of 430 to SRA_submission.tar
# Adding file 97 of 430 to SRA_submission.tar
# Adding file 98 of 430 to SRA_submission.tar
# Adding file 99 of 430 to SRA_submission.tar
# Adding file 100 of 430 to SRA_submission.tar
# Adding file 101 of 430 to SRA_submission.tar
# Adding file 102 of 430 to SRA_submission.tar
# Adding file 103 of 430 to SRA_submission.tar
# Adding file 104 of 430 to SRA_submission.tar
# Adding file 105 of 430 to SRA_submission.tar
# Adding file 106 of 430 to SRA_submission.tar
# Adding file 107 of 430 to SRA_submission.tar
# Adding file 108 of 430 to SRA_submission.tar
# Adding file 109 of 430 to SRA_submission.tar
# Adding file 110 of 430 to SRA_submission.tar
# Adding file 111 of 430 to SRA_submission.tar
# Adding file 112 of 430 to SRA_submission.tar
# Adding file 113 of 430 to SRA_submission.tar
# Adding file 114 of 430 to SRA_submission.tar
# Adding file 115 of 430 to SRA_submission.tar
# Adding file 116 of 430 to SRA_submission.tar
# Adding file 117 of 430 to SRA_submission.tar
# Adding file 118 of 430 to SRA_submission.tar
# Adding file 119 of 430 to SRA_submission.tar
# Adding file 120 of 430 to SRA_submission.tar
# Adding file 121 of 430 to SRA_submission.tar
# Adding file 122 of 430 to SRA_submission.tar
# Adding file 123 of 430 to SRA_submission.tar
# Adding file 124 of 430 to SRA_submission.tar
# Adding file 125 of 430 to SRA_submission.tar
# Adding file 126 of 430 to SRA_submission.tar
# Adding file 127 of 430 to SRA_submission.tar
# Adding file 128 of 430 to SRA_submission.tar
# Adding file 129 of 430 to SRA_submission.tar
# Adding file 130 of 430 to SRA_submission.tar
# Adding file 131 of 430 to SRA_submission.tar
# Adding file 132 of 430 to SRA_submission.tar
# Adding file 133 of 430 to SRA_submission.tar
# Adding file 134 of 430 to SRA_submission.tar
# Adding file 135 of 430 to SRA_submission.tar
# Adding file 136 of 430 to SRA_submission.tar
# Adding file 137 of 430 to SRA_submission.tar
# Adding file 138 of 430 to SRA_submission.tar
# Adding file 139 of 430 to SRA_submission.tar
# Adding file 140 of 430 to SRA_submission.tar
# Adding file 141 of 430 to SRA_submission.tar
# Adding file 142 of 430 to SRA_submission.tar
# Adding file 143 of 430 to SRA_submission.tar
# Adding file 144 of 430 to SRA_submission.tar
# Adding file 145 of 430 to SRA_submission.tar
# Adding file 146 of 430 to SRA_submission.tar
# Adding file 147 of 430 to SRA_submission.tar
# Adding file 148 of 430 to SRA_submission.tar
# Adding file 149 of 430 to SRA_submission.tar
# Adding file 150 of 430 to SRA_submission.tar
# Adding file 151 of 430 to SRA_submission.tar
# Adding file 152 of 430 to SRA_submission.tar
# Adding file 153 of 430 to SRA_submission.tar
# Adding file 154 of 430 to SRA_submission.tar
# Adding file 155 of 430 to SRA_submission.tar
# Adding file 156 of 430 to SRA_submission.tar
# Adding file 157 of 430 to SRA_submission.tar
# Adding file 158 of 430 to SRA_submission.tar
# Adding file 159 of 430 to SRA_submission.tar
# Adding file 160 of 430 to SRA_submission.tar
# Adding file 161 of 430 to SRA_submission.tar
# Adding file 162 of 430 to SRA_submission.tar
# Adding file 163 of 430 to SRA_submission.tar
# Adding file 164 of 430 to SRA_submission.tar
# Adding file 165 of 430 to SRA_submission.tar
# Adding file 166 of 430 to SRA_submission.tar
# Adding file 167 of 430 to SRA_submission.tar
# Adding file 168 of 430 to SRA_submission.tar
# Adding file 169 of 430 to SRA_submission.tar
# Adding file 170 of 430 to SRA_submission.tar
# Adding file 171 of 430 to SRA_submission.tar
# Adding file 172 of 430 to SRA_submission.tar
# Adding file 173 of 430 to SRA_submission.tar
# Adding file 174 of 430 to SRA_submission.tar
# Adding file 175 of 430 to SRA_submission.tar
# Adding file 176 of 430 to SRA_submission.tar
# Adding file 177 of 430 to SRA_submission.tar
# Adding file 178 of 430 to SRA_submission.tar
# Adding file 179 of 430 to SRA_submission.tar
# Adding file 180 of 430 to SRA_submission.tar
# Adding file 181 of 430 to SRA_submission.tar
# Adding file 182 of 430 to SRA_submission.tar
# Adding file 183 of 430 to SRA_submission.tar
# Adding file 184 of 430 to SRA_submission.tar
# Adding file 185 of 430 to SRA_submission.tar
# Adding file 186 of 430 to SRA_submission.tar
# Adding file 187 of 430 to SRA_submission.tar
# Adding file 188 of 430 to SRA_submission.tar
# Adding file 189 of 430 to SRA_submission.tar
# Adding file 190 of 430 to SRA_submission.tar
# Adding file 191 of 430 to SRA_submission.tar
# Adding file 192 of 430 to SRA_submission.tar
# Adding file 193 of 430 to SRA_submission.tar
# Adding file 194 of 430 to SRA_submission.tar
# Adding file 195 of 430 to SRA_submission.tar
# Adding file 196 of 430 to SRA_submission.tar
# Adding file 197 of 430 to SRA_submission.tar
# Adding file 198 of 430 to SRA_submission.tar
# Adding file 199 of 430 to SRA_submission.tar
# Adding file 200 of 430 to SRA_submission.tar
# Adding file 201 of 430 to SRA_submission.tar
# Adding file 202 of 430 to SRA_submission.tar
# Adding file 203 of 430 to SRA_submission.tar
# Adding file 204 of 430 to SRA_submission.tar
# Adding file 205 of 430 to SRA_submission.tar
# Adding file 206 of 430 to SRA_submission.tar
# Adding file 207 of 430 to SRA_submission.tar
# Adding file 208 of 430 to SRA_submission.tar
# Adding file 209 of 430 to SRA_submission.tar
# Adding file 210 of 430 to SRA_submission.tar
# Adding file 211 of 430 to SRA_submission.tar
# Adding file 212 of 430 to SRA_submission.tar
# Adding file 213 of 430 to SRA_submission.tar
# Adding file 214 of 430 to SRA_submission.tar
# Adding file 215 of 430 to SRA_submission.tar
# Adding file 216 of 430 to SRA_submission.tar
# Adding file 217 of 430 to SRA_submission.tar
# Adding file 218 of 430 to SRA_submission.tar
# Adding file 219 of 430 to SRA_submission.tar
# Adding file 220 of 430 to SRA_submission.tar
# Adding file 221 of 430 to SRA_submission.tar
# Adding file 222 of 430 to SRA_submission.tar
# Adding file 223 of 430 to SRA_submission.tar
# Adding file 224 of 430 to SRA_submission.tar
# Adding file 225 of 430 to SRA_submission.tar
# Adding file 226 of 430 to SRA_submission.tar
# Adding file 227 of 430 to SRA_submission.tar
# Adding file 228 of 430 to SRA_submission.tar
# Adding file 229 of 430 to SRA_submission.tar
# Adding file 230 of 430 to SRA_submission.tar
# Adding file 231 of 430 to SRA_submission.tar
# Adding file 232 of 430 to SRA_submission.tar
# Adding file 233 of 430 to SRA_submission.tar
# Adding file 234 of 430 to SRA_submission.tar
# Adding file 235 of 430 to SRA_submission.tar
# Adding file 236 of 430 to SRA_submission.tar
# Adding file 237 of 430 to SRA_submission.tar
# Adding file 238 of 430 to SRA_submission.tar
# Adding file 239 of 430 to SRA_submission.tar
# Adding file 240 of 430 to SRA_submission.tar
# Adding file 241 of 430 to SRA_submission.tar
# Adding file 242 of 430 to SRA_submission.tar
# Adding file 243 of 430 to SRA_submission.tar
# Adding file 244 of 430 to SRA_submission.tar
# Adding file 245 of 430 to SRA_submission.tar
# Adding file 246 of 430 to SRA_submission.tar
# Adding file 247 of 430 to SRA_submission.tar
# Adding file 248 of 430 to SRA_submission.tar
# Adding file 249 of 430 to SRA_submission.tar
# Adding file 250 of 430 to SRA_submission.tar
# Adding file 251 of 430 to SRA_submission.tar
# Adding file 252 of 430 to SRA_submission.tar
# Adding file 253 of 430 to SRA_submission.tar
# Adding file 254 of 430 to SRA_submission.tar
# Adding file 255 of 430 to SRA_submission.tar
# Adding file 256 of 430 to SRA_submission.tar
# Adding file 257 of 430 to SRA_submission.tar
# Adding file 258 of 430 to SRA_submission.tar
# Adding file 259 of 430 to SRA_submission.tar
# Adding file 260 of 430 to SRA_submission.tar
# Adding file 261 of 430 to SRA_submission.tar
# Adding file 262 of 430 to SRA_submission.tar
# Adding file 263 of 430 to SRA_submission.tar
# Adding file 264 of 430 to SRA_submission.tar
# Adding file 265 of 430 to SRA_submission.tar
# Adding file 266 of 430 to SRA_submission.tar
# Adding file 267 of 430 to SRA_submission.tar
# Adding file 268 of 430 to SRA_submission.tar
# Adding file 269 of 430 to SRA_submission.tar
# Adding file 270 of 430 to SRA_submission.tar
# Adding file 271 of 430 to SRA_submission.tar
# Adding file 272 of 430 to SRA_submission.tar
# Adding file 273 of 430 to SRA_submission.tar
# Adding file 274 of 430 to SRA_submission.tar
# Adding file 275 of 430 to SRA_submission.tar
# Adding file 276 of 430 to SRA_submission.tar
# Adding file 277 of 430 to SRA_submission.tar
# Adding file 278 of 430 to SRA_submission.tar
# Adding file 279 of 430 to SRA_submission.tar
# Adding file 280 of 430 to SRA_submission.tar
# Adding file 281 of 430 to SRA_submission.tar
# Adding file 282 of 430 to SRA_submission.tar
# Adding file 283 of 430 to SRA_submission.tar
# Adding file 284 of 430 to SRA_submission.tar
# Adding file 285 of 430 to SRA_submission.tar
# Adding file 286 of 430 to SRA_submission.tar
# Adding file 287 of 430 to SRA_submission.tar
# Adding file 288 of 430 to SRA_submission.tar
# Adding file 289 of 430 to SRA_submission.tar
# Adding file 290 of 430 to SRA_submission.tar
# Adding file 291 of 430 to SRA_submission.tar
# Adding file 292 of 430 to SRA_submission.tar
# Adding file 293 of 430 to SRA_submission.tar
# Adding file 294 of 430 to SRA_submission.tar
# Adding file 295 of 430 to SRA_submission.tar
# Adding file 296 of 430 to SRA_submission.tar
# Adding file 297 of 430 to SRA_submission.tar
# Adding file 298 of 430 to SRA_submission.tar
# Adding file 299 of 430 to SRA_submission.tar
# Adding file 300 of 430 to SRA_submission.tar
# Adding file 301 of 430 to SRA_submission.tar
# Adding file 302 of 430 to SRA_submission.tar
# Adding file 303 of 430 to SRA_submission.tar
# Adding file 304 of 430 to SRA_submission.tar
# Adding file 305 of 430 to SRA_submission.tar
# Adding file 306 of 430 to SRA_submission.tar
# Adding file 307 of 430 to SRA_submission.tar
# Adding file 308 of 430 to SRA_submission.tar
# Adding file 309 of 430 to SRA_submission.tar
# Adding file 310 of 430 to SRA_submission.tar
# Adding file 311 of 430 to SRA_submission.tar
# Adding file 312 of 430 to SRA_submission.tar
# Adding file 313 of 430 to SRA_submission.tar
# Adding file 314 of 430 to SRA_submission.tar
# Adding file 315 of 430 to SRA_submission.tar
# Adding file 316 of 430 to SRA_submission.tar
# Adding file 317 of 430 to SRA_submission.tar
# Adding file 318 of 430 to SRA_submission.tar
# Adding file 319 of 430 to SRA_submission.tar
# Adding file 320 of 430 to SRA_submission.tar
# Adding file 321 of 430 to SRA_submission.tar
# Adding file 322 of 430 to SRA_submission.tar
# Adding file 323 of 430 to SRA_submission.tar
# Adding file 324 of 430 to SRA_submission.tar
# Adding file 325 of 430 to SRA_submission.tar
# Adding file 326 of 430 to SRA_submission.tar
# Adding file 327 of 430 to SRA_submission.tar
# Adding file 328 of 430 to SRA_submission.tar
# Adding file 329 of 430 to SRA_submission.tar
# Adding file 330 of 430 to SRA_submission.tar
# Adding file 331 of 430 to SRA_submission.tar
# Adding file 332 of 430 to SRA_submission.tar
# Adding file 333 of 430 to SRA_submission.tar
# Adding file 334 of 430 to SRA_submission.tar
# Adding file 335 of 430 to SRA_submission.tar
# Adding file 336 of 430 to SRA_submission.tar
# Adding file 337 of 430 to SRA_submission.tar
# Adding file 338 of 430 to SRA_submission.tar
# Adding file 339 of 430 to SRA_submission.tar
# Adding file 340 of 430 to SRA_submission.tar
# Adding file 341 of 430 to SRA_submission.tar
# Adding file 342 of 430 to SRA_submission.tar
# Adding file 343 of 430 to SRA_submission.tar
# Adding file 344 of 430 to SRA_submission.tar
# Adding file 345 of 430 to SRA_submission.tar
# Adding file 346 of 430 to SRA_submission.tar
# Adding file 347 of 430 to SRA_submission.tar
# Adding file 348 of 430 to SRA_submission.tar
# Adding file 349 of 430 to SRA_submission.tar
# Adding file 350 of 430 to SRA_submission.tar
# Adding file 351 of 430 to SRA_submission.tar
# Adding file 352 of 430 to SRA_submission.tar
# Adding file 353 of 430 to SRA_submission.tar
# Adding file 354 of 430 to SRA_submission.tar
# Adding file 355 of 430 to SRA_submission.tar
# Adding file 356 of 430 to SRA_submission.tar
# Adding file 357 of 430 to SRA_submission.tar
# Adding file 358 of 430 to SRA_submission.tar
# Adding file 359 of 430 to SRA_submission.tar
# Adding file 360 of 430 to SRA_submission.tar
# Adding file 361 of 430 to SRA_submission.tar
# Adding file 362 of 430 to SRA_submission.tar
# Adding file 363 of 430 to SRA_submission.tar
# Adding file 364 of 430 to SRA_submission.tar
# Adding file 365 of 430 to SRA_submission.tar
# Adding file 366 of 430 to SRA_submission.tar
# Adding file 367 of 430 to SRA_submission.tar
# Adding file 368 of 430 to SRA_submission.tar
# Adding file 369 of 430 to SRA_submission.tar
# Adding file 370 of 430 to SRA_submission.tar
# Adding file 371 of 430 to SRA_submission.tar
# Adding file 372 of 430 to SRA_submission.tar
# Adding file 373 of 430 to SRA_submission.tar
# Adding file 374 of 430 to SRA_submission.tar
# Adding file 375 of 430 to SRA_submission.tar
# Adding file 376 of 430 to SRA_submission.tar
# Adding file 377 of 430 to SRA_submission.tar
# Adding file 378 of 430 to SRA_submission.tar
# Adding file 379 of 430 to SRA_submission.tar
# Adding file 380 of 430 to SRA_submission.tar
# Adding file 381 of 430 to SRA_submission.tar
# Adding file 382 of 430 to SRA_submission.tar
# Adding file 383 of 430 to SRA_submission.tar
# Adding file 384 of 430 to SRA_submission.tar
# Adding file 385 of 430 to SRA_submission.tar
# Adding file 386 of 430 to SRA_submission.tar
# Adding file 387 of 430 to SRA_submission.tar
# Adding file 388 of 430 to SRA_submission.tar
# Adding file 389 of 430 to SRA_submission.tar
# Adding file 390 of 430 to SRA_submission.tar
# Adding file 391 of 430 to SRA_submission.tar
# Adding file 392 of 430 to SRA_submission.tar
# Adding file 393 of 430 to SRA_submission.tar
# Adding file 394 of 430 to SRA_submission.tar
# Adding file 395 of 430 to SRA_submission.tar
# Adding file 396 of 430 to SRA_submission.tar
# Adding file 397 of 430 to SRA_submission.tar
# Adding file 398 of 430 to SRA_submission.tar
# Adding file 399 of 430 to SRA_submission.tar
# Adding file 400 of 430 to SRA_submission.tar
# Adding file 401 of 430 to SRA_submission.tar
# Adding file 402 of 430 to SRA_submission.tar
# Adding file 403 of 430 to SRA_submission.tar
# Adding file 404 of 430 to SRA_submission.tar
# Adding file 405 of 430 to SRA_submission.tar
# Adding file 406 of 430 to SRA_submission.tar
# Adding file 407 of 430 to SRA_submission.tar
# Adding file 408 of 430 to SRA_submission.tar
# Adding file 409 of 430 to SRA_submission.tar
# Adding file 410 of 430 to SRA_submission.tar
# Adding file 411 of 430 to SRA_submission.tar
# Adding file 412 of 430 to SRA_submission.tar
# Adding file 413 of 430 to SRA_submission.tar
# Adding file 414 of 430 to SRA_submission.tar
# Adding file 415 of 430 to SRA_submission.tar
# Adding file 416 of 430 to SRA_submission.tar
# Adding file 417 of 430 to SRA_submission.tar
# Adding file 418 of 430 to SRA_submission.tar
# Adding file 419 of 430 to SRA_submission.tar
# Adding file 420 of 430 to SRA_submission.tar
# Adding file 421 of 430 to SRA_submission.tar
# Adding file 422 of 430 to SRA_submission.tar
# Adding file 423 of 430 to SRA_submission.tar
# Adding file 424 of 430 to SRA_submission.tar
# Adding file 425 of 430 to SRA_submission.tar
# Adding file 426 of 430 to SRA_submission.tar
# Adding file 427 of 430 to SRA_submission.tar
# Adding file 428 of 430 to SRA_submission.tar
# Adding file 429 of 430 to SRA_submission.tar
# Adding file 430 of 430 to SRA_submission.tar
# Added all files to SRA_submission.tar

# %% [markdown]
# See the size of the `*.tar` file to upload and make sure it has the expected files:

# %%
print(f"The size of {tar_filename} is {os.path.getsize(tar_filename) / 1e9:.1f} GB")

with tarfile.open(tar_filename) as f:
    files_in_tar = set(f.getnames())
if files_in_tar == set(fastqs['filename']):
    print(f"{tar_filename} contains all {len(files_in_tar)} expected files.")
else:
    raise ValueError(f"{tar_filename} does not have all the expected files.")
# Out:
# The size of SRA_submission.tar is 59.2 GB
# SRA_submission.tar contains all 430 expected files.

# %% [markdown]
# We now read in the details about doing the FTP upload to the SRA.
# Note that these are set in separate files already:

# %%
# the following are provided by SRA wizard insturctions
ftp_address = 'ftp-private.ncbi.nlm.nih.gov'
ftp_username = config['ftp_username'].strip()
ftp_account_folder = config['ftp_account_folder'].strip()
ftp_subfolder = config['ftp_subfolder'].strip()
with open('ftp_password.txt') as f:
    ftp_password = f.read().strip()

# %% [markdown]
# Now create FTP connection and upload the TAR file.
# Note that this takes a while.
# If you are worried that it will timeout given the size of your file, you can run this notebook via `slurm` so there is no timing out:

# %%
print(f"Starting upload at {datetime.datetime.now()}")

with ftplib.FTP(ftp_address) as ftp:
    ftp.login(user=ftp_username,
              passwd=ftp_password,
              )
    ftp.cwd(ftp_account_folder)
    ftp.mkd(ftp_subfolder)
    ftp.cwd(ftp_subfolder)
    with open(tar_filename, 'rb') as f:
        ftp.storbinary(f"STOR {tar_filename}", f)
        
print(f"Finished upload at {datetime.datetime.now()}")
# Out:
# Starting upload at 2023-04-26 14:05:26.548175
# Finished upload at 2023-04-26 16:51:58.641591
